# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import requests
import time
from scipy.stats import linregress
from citipy import citipy

#import API key
from api_keys import weather_api_key

lat_range = (-90, 90)
lng_range = (-180, 180)

#file
output_data_file = "output_data/cities.csv"

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# URL for Weather Map API 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f2e7be3fbf6a6ca5ee22f83c7998246c"

# List the city data
city_data = []

# Print 
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | hami
# Processing Record 4 of Set 1 | tiksi
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | kisangani
# Processing Record 7 of Set 1 | castro
# Processing Record 8 of Set 1 | diphu
# Processing Record 9 of Set 1 | kaitangata
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | mount gambier
# Processing Record 12 of Set 1 | leningradskiy
# Processing Record 13 of Set 1 | cabo san lucas
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | mogadishu
# Processing Record 16 of Set 1 | hobyo
# Processing Record 17 of Set 1 | luanda
# Processing Record 18 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 1 | prainha
# Processing Record 20 of Set 1 | shenjiamen
# Processing Record 21 of Set 1 | dunedin
# Processing Record 22 of Set 1 | jacqueville
# Processing Record 23 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | victoria
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | hamilton
# Processing Record 28 of Set 1 | rankovce
# Processing Record 29 of Set 1 | belmonte
# Processing Record 30 of Set 1 | airai
# Processing Record 31 of Set 1 | kampot
# Processing Record 32 of Set 1 | olafsvik
# Processing Record 33 of Set 1 | khatanga
# Processing Record 34 of Set 1 | inta
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | marawi
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | luganville
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | camacha
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | vigrestad
# Processing Record 44 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 1 | vao
# Processing Record 46 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 1 | tual
# Processing Record 48 of Set 1 | phan thiet
# Processing Record 49 of Set 1 | tafo
# Processing Record 50 of Set 1 | pontalina
# Processing Record 0 of Set 2 | codrington
# Processing Record 1 of Set 2 | kem
# Processing Record 2 of Set 2 | lerwick
# Processing Record 3 of Set 2 | ilulissat
# Processing Record 4 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 2 | lyuban
# Processing Record 7 of Set 2 | novoorsk
# Processing Record 8 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 2 | yulara
# Processing Record 10 of Set 2 | upernavik
# Processing Record 11 of Set 2 | kenitra
# Processing Record 12 of Set 2 | gat
# Processing Record 13 of Set 2 | copiapo
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | burica
# City not found. Skipping...
# Processing Record 16 of Set 2 | chokurdakh
# Processing Record 17 of Set 2 | chuy
# Processing Record 18 of Set 2 | puerto colombia
# Processing Record 19 of Set 2 | saraland
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | ye
# City not found. Skipping...
# Processing Record 22 of Set 2 | tasiilaq
# Processing Record 23 of Set 2 | fortuna
# Processing Record 24 of Set 2 | ribeira grande
# Processing Record 25 of Set 2 | te anau
# Processing Record 26 of Set 2 | altay
# Processing Record 27 of Set 2 | krasnoselkup
# Processing Record 28 of Set 2 | quatre cocos
# Processing Record 29 of Set 2 | altamira
# Processing Record 30 of Set 2 | coquimbo
# Processing Record 31 of Set 2 | aguie
# Processing Record 32 of Set 2 | belozerskoye
# Processing Record 33 of Set 2 | saldanha
# Processing Record 34 of Set 2 | dikson
# Processing Record 35 of Set 2 | bukama
# Processing Record 36 of Set 2 | sakakah
# Processing Record 37 of Set 2 | takoradi
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | ushuaia
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | georgetown
# Processing Record 43 of Set 2 | amapa
# Processing Record 44 of Set 2 | karratha
# Processing Record 45 of Set 2 | namibe
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | nome
# Processing Record 48 of Set 2 | nanortalik
# Processing Record 49 of Set 2 | albany
# Processing Record 0 of Set 3 | lithakia
# Processing Record 1 of Set 3 | wundanyi
# Processing Record 2 of Set 3 | bluff
# Processing Record 3 of Set 3 | sinnamary
# Processing Record 4 of Set 3 | nikolskoye
# Processing Record 5 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 3 | pangnirtung
# Processing Record 7 of Set 3 | pamekasan
# Processing Record 8 of Set 3 | egvekinot
# Processing Record 9 of Set 3 | snezhnogorsk
# Processing Record 10 of Set 3 | brasilia de minas
# Processing Record 11 of Set 3 | gangotri
# City not found. Skipping...
# Processing Record 12 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 3 | namatanai
# Processing Record 14 of Set 3 | saint-philippe
# Processing Record 15 of Set 3 | solano
# Processing Record 16 of Set 3 | hasaki
# Processing Record 17 of Set 3 | east london
# Processing Record 18 of Set 3 | buala
# Processing Record 19 of Set 3 | tazovskiy
# Processing Record 20 of Set 3 | hofn
# Processing Record 21 of Set 3 | verkhnevilyuysk
# Processing Record 22 of Set 3 | pitimbu
# Processing Record 23 of Set 3 | huicungo
# Processing Record 24 of Set 3 | hun
# Processing Record 25 of Set 3 | marzuq
# Processing Record 26 of Set 3 | vitim
# Processing Record 27 of Set 3 | buariki
# City not found. Skipping...
# Processing Record 28 of Set 3 | makakilo city
# Processing Record 29 of Set 3 | vaini
# Processing Record 30 of Set 3 | los angeles
# Processing Record 31 of Set 3 | muswellbrook
# Processing Record 32 of Set 3 | esperance
# Processing Record 33 of Set 3 | bredasdorp
# Processing Record 34 of Set 3 | temryuk
# Processing Record 35 of Set 3 | xinpu
# Processing Record 36 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 3 | manggar
# Processing Record 39 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 3 | souillac
# Processing Record 41 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 3 | cuenca
# Processing Record 43 of Set 3 | kieta
# Processing Record 44 of Set 3 | nyurba
# Processing Record 45 of Set 3 | san patricio
# Processing Record 46 of Set 3 | the valley
# Processing Record 47 of Set 3 | mbanza-ngungu
# Processing Record 48 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 3 | iqaluit
# Processing Record 0 of Set 4 | pisco
# Processing Record 1 of Set 4 | brae
# Processing Record 2 of Set 4 | zherdevka
# Processing Record 3 of Set 4 | batagay-alyta
# Processing Record 4 of Set 4 | zalantun
# Processing Record 5 of Set 4 | innisfail
# Processing Record 6 of Set 4 | port elizabeth
# Processing Record 7 of Set 4 | lebu
# Processing Record 8 of Set 4 | cabinda
# Processing Record 9 of Set 4 | maroua
# Processing Record 10 of Set 4 | maniitsoq
# Processing Record 11 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 12 of Set 4 | inuvik
# Processing Record 13 of Set 4 | meulaboh
# Processing Record 14 of Set 4 | monrovia
# Processing Record 15 of Set 4 | port alfred
# Processing Record 16 of Set 4 | port-gentil
# Processing Record 17 of Set 4 | labuhan
# Processing Record 18 of Set 4 | superior
# Processing Record 19 of Set 4 | garissa
# Processing Record 20 of Set 4 | raudeberg
# Processing Record 21 of Set 4 | iberia
# Processing Record 22 of Set 4 | piacabucu
# Processing Record 23 of Set 4 | tir pol
# City not found. Skipping...
# Processing Record 24 of Set 4 | axim
# Processing Record 25 of Set 4 | srednekolymsk
# Processing Record 26 of Set 4 | praia da vitoria
# Processing Record 27 of Set 4 | werda
# Processing Record 28 of Set 4 | la ronge
# Processing Record 29 of Set 4 | kharan
# Processing Record 30 of Set 4 | tabas
# Processing Record 31 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 4 | broken hill
# Processing Record 33 of Set 4 | richards bay
# Processing Record 34 of Set 4 | ketchikan
# Processing Record 35 of Set 4 | bose
# Processing Record 36 of Set 4 | hithadhoo
# Processing Record 37 of Set 4 | san quintin
# Processing Record 38 of Set 4 | baiyin
# Processing Record 39 of Set 4 | sembe
# Processing Record 40 of Set 4 | kajaani
# Processing Record 41 of Set 4 | khani
# Processing Record 42 of Set 4 | le port
# Processing Record 43 of Set 4 | vila franca do campo
# Processing Record 44 of Set 4 | kasiri
# Processing Record 45 of Set 4 | kodiak
# Processing Record 46 of Set 4 | whitehorse
# Processing Record 47 of Set 4 | linxia
# Processing Record 48 of Set 4 | dwarka
# Processing Record 49 of Set 4 | longyearbyen
# Processing Record 0 of Set 5 | tutoia
# Processing Record 1 of Set 5 | san ramon
# Processing Record 2 of Set 5 | phalaborwa
# Processing Record 3 of Set 5 | pochutla
# Processing Record 4 of Set 5 | mahebourg
# Processing Record 5 of Set 5 | muros
# Processing Record 6 of Set 5 | soyo
# Processing Record 7 of Set 5 | sesheke
# Processing Record 8 of Set 5 | trincomalee
# Processing Record 9 of Set 5 | havre-saint-pierre
# Processing Record 10 of Set 5 | pachino
# Processing Record 11 of Set 5 | porto walter
# Processing Record 12 of Set 5 | teguise
# Processing Record 13 of Set 5 | bytow
# Processing Record 14 of Set 5 | bambous virieux
# Processing Record 15 of Set 5 | tromso
# Processing Record 16 of Set 5 | talnakh
# Processing Record 17 of Set 5 | vostok
# Processing Record 18 of Set 5 | nemuro
# Processing Record 19 of Set 5 | bullhead city
# Processing Record 20 of Set 5 | broome
# Processing Record 21 of Set 5 | zlobin
# Processing Record 22 of Set 5 | bengkulu
# Processing Record 23 of Set 5 | lakes entrance
# Processing Record 24 of Set 5 | sundargarh
# Processing Record 25 of Set 5 | lamar
# Processing Record 26 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 27 of Set 5 | almunecar
# Processing Record 28 of Set 5 | leh
# Processing Record 29 of Set 5 | huescar
# Processing Record 30 of Set 5 | imbituba
# Processing Record 31 of Set 5 | palmerston
# Processing Record 32 of Set 5 | cuamba
# Processing Record 33 of Set 5 | guerrero negro
# Processing Record 34 of Set 5 | fayaoue
# Processing Record 35 of Set 5 | zolotinka
# City not found. Skipping...
# Processing Record 36 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 37 of Set 5 | norman wells
# Processing Record 38 of Set 5 | vossevangen
# Processing Record 39 of Set 5 | arman
# Processing Record 40 of Set 5 | jilin
# Processing Record 41 of Set 5 | kavaratti
# Processing Record 42 of Set 5 | clyde river
# Processing Record 43 of Set 5 | xilopolis
# Processing Record 44 of Set 5 | novyye lyady
# Processing Record 45 of Set 5 | miandrivazo
# Processing Record 46 of Set 5 | boa vista
# Processing Record 47 of Set 5 | xingcheng
# Processing Record 48 of Set 5 | sanmenxia
# Processing Record 49 of Set 5 | jiujiang
# Processing Record 0 of Set 6 | provideniya
# Processing Record 1 of Set 6 | presidencia roque saenz pena
# Processing Record 2 of Set 6 | tabou
# Processing Record 3 of Set 6 | kentau
# Processing Record 4 of Set 6 | oranjemund
# Processing Record 5 of Set 6 | thompson
# Processing Record 6 of Set 6 | komsomolskiy
# Processing Record 7 of Set 6 | cherskiy
# Processing Record 8 of Set 6 | aswan
# Processing Record 9 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 10 of Set 6 | auka
# Processing Record 11 of Set 6 | iseyin
# Processing Record 12 of Set 6 | husavik
# Processing Record 13 of Set 6 | arraial do cabo
# Processing Record 14 of Set 6 | port lincoln
# Processing Record 15 of Set 6 | dudinka
# Processing Record 16 of Set 6 | manturovo
# Processing Record 17 of Set 6 | baykit
# Processing Record 18 of Set 6 | kapaa
# Processing Record 19 of Set 6 | calbuco
# Processing Record 20 of Set 6 | puerto del rosario
# Processing Record 21 of Set 6 | at-bashi
# Processing Record 22 of Set 6 | mount isa
# Processing Record 23 of Set 6 | joshimath
# Processing Record 24 of Set 6 | severo-kurilsk
# Processing Record 25 of Set 6 | matamoros
# Processing Record 26 of Set 6 | ksenyevka
# City not found. Skipping...
# Processing Record 27 of Set 6 | langxiang
# Processing Record 28 of Set 6 | toamasina
# Processing Record 29 of Set 6 | malanje
# Processing Record 30 of Set 6 | chegdomyn
# Processing Record 31 of Set 6 | vardo
# Processing Record 32 of Set 6 | belen
# Processing Record 33 of Set 6 | panalingaan
# Processing Record 34 of Set 6 | tevaitoa
# Processing Record 35 of Set 6 | katsuura
# Processing Record 36 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 6 | katobu
# Processing Record 38 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 6 | kununurra
# Processing Record 40 of Set 6 | palmer
# Processing Record 41 of Set 6 | darovskoy
# Processing Record 42 of Set 6 | flin flon
# Processing Record 43 of Set 6 | santa maria do suacui
# Processing Record 44 of Set 6 | donnacona
# Processing Record 45 of Set 6 | vanavara
# Processing Record 46 of Set 6 | xichang
# Processing Record 47 of Set 6 | pombal
# Processing Record 48 of Set 6 | huazolotitlan
# City not found. Skipping...
# Processing Record 49 of Set 6 | kavieng
# Processing Record 0 of Set 7 | tymovskoye
# Processing Record 1 of Set 7 | saint george
# Processing Record 2 of Set 7 | banda aceh
# Processing Record 3 of Set 7 | lircay
# Processing Record 4 of Set 7 | gusau
# Processing Record 5 of Set 7 | grindavik
# Processing Record 6 of Set 7 | nakambala
# Processing Record 7 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 7 | araouane
# Processing Record 9 of Set 7 | margate
# Processing Record 10 of Set 7 | kudahuvadhoo
# Processing Record 11 of Set 7 | russell
# Processing Record 12 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 13 of Set 7 | kalmunai
# Processing Record 14 of Set 7 | coahuayana
# Processing Record 15 of Set 7 | kepno
# Processing Record 16 of Set 7 | hambantota
# Processing Record 17 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 7 | lompoc
# Processing Record 19 of Set 7 | faanui
# Processing Record 20 of Set 7 | methoni
# Processing Record 21 of Set 7 | laguna
# Processing Record 22 of Set 7 | ponta do sol
# Processing Record 23 of Set 7 | ahipara
# Processing Record 24 of Set 7 | ken caryl
# Processing Record 25 of Set 7 | novyy urengoy
# Processing Record 26 of Set 7 | udachnyy
# Processing Record 27 of Set 7 | eureka
# Processing Record 28 of Set 7 | mar del plata
# Processing Record 29 of Set 7 | auce
# Processing Record 30 of Set 7 | alofi
# Processing Record 31 of Set 7 | puerto leguizamo
# Processing Record 32 of Set 7 | gustrow
# Processing Record 33 of Set 7 | luderitz
# Processing Record 34 of Set 7 | baherden
# Processing Record 35 of Set 7 | amarante do maranhao
# Processing Record 36 of Set 7 | svarstad
# Processing Record 37 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 7 | tuntum
# Processing Record 39 of Set 7 | tuim
# Processing Record 40 of Set 7 | araguacu
# Processing Record 41 of Set 7 | mecca
# Processing Record 42 of Set 7 | sturgis
# Processing Record 43 of Set 7 | santo nino
# Processing Record 44 of Set 7 | kahului
# Processing Record 45 of Set 7 | rio gallegos
# Processing Record 46 of Set 7 | xining
# Processing Record 47 of Set 7 | necochea
# Processing Record 48 of Set 7 | saint anthony
# Processing Record 49 of Set 7 | monclova
# Processing Record 0 of Set 8 | vila velha
# Processing Record 1 of Set 8 | badou
# Processing Record 2 of Set 8 | tautira
# Processing Record 3 of Set 8 | lagoa
# Processing Record 4 of Set 8 | boundiali
# Processing Record 5 of Set 8 | marand
# Processing Record 6 of Set 8 | mangile
# City not found. Skipping...
# Processing Record 7 of Set 8 | carnarvon
# Processing Record 8 of Set 8 | villa vazquez
# City not found. Skipping...
# Processing Record 9 of Set 8 | moussoro
# Processing Record 10 of Set 8 | smithers
# Processing Record 11 of Set 8 | nuuk
# Processing Record 12 of Set 8 | narsaq
# Processing Record 13 of Set 8 | buin
# Processing Record 14 of Set 8 | padang
# Processing Record 15 of Set 8 | coria
# Processing Record 16 of Set 8 | atar
# Processing Record 17 of Set 8 | shingu
# Processing Record 18 of Set 8 | gizo
# Processing Record 19 of Set 8 | burns lake
# Processing Record 20 of Set 8 | praia
# Processing Record 21 of Set 8 | christchurch
# Processing Record 22 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 23 of Set 8 | fort madison
# Processing Record 24 of Set 8 | sandur
# Processing Record 25 of Set 8 | fort walton beach
# Processing Record 26 of Set 8 | guangyuan
# Processing Record 27 of Set 8 | guymon
# Processing Record 28 of Set 8 | rio grande
# Processing Record 29 of Set 8 | porto novo
# Processing Record 30 of Set 8 | miles city
# Processing Record 31 of Set 8 | oussouye
# Processing Record 32 of Set 8 | adwa
# Processing Record 33 of Set 8 | sao jose da coroa grande
# Processing Record 34 of Set 8 | san ignacio
# Processing Record 35 of Set 8 | ihosy
# Processing Record 36 of Set 8 | hanna
# Processing Record 37 of Set 8 | kaeo
# Processing Record 38 of Set 8 | chapais
# Processing Record 39 of Set 8 | murray bridge
# Processing Record 40 of Set 8 | lorengau
# Processing Record 41 of Set 8 | myitkyina
# Processing Record 42 of Set 8 | marion
# Processing Record 43 of Set 8 | wuwei
# Processing Record 44 of Set 8 | yaguaron
# Processing Record 45 of Set 8 | gunjur
# Processing Record 46 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 47 of Set 8 | cortez
# Processing Record 48 of Set 8 | sorland
# Processing Record 49 of Set 8 | onguday
# Processing Record 0 of Set 9 | rafai
# Processing Record 1 of Set 9 | cidreira
# Processing Record 2 of Set 9 | hirara
# Processing Record 3 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 4 of Set 9 | ardesen
# Processing Record 5 of Set 9 | alice springs
# Processing Record 6 of Set 9 | lavrentiya
# Processing Record 7 of Set 9 | mangrol
# Processing Record 8 of Set 9 | manado
# Processing Record 9 of Set 9 | nantucket
# Processing Record 10 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 11 of Set 9 | vallenar
# Processing Record 12 of Set 9 | belyy yar
# Processing Record 13 of Set 9 | aklavik
# Processing Record 14 of Set 9 | sabang
# Processing Record 15 of Set 9 | sao filipe
# Processing Record 16 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 17 of Set 9 | erzin
# Processing Record 18 of Set 9 | rongcheng
# Processing Record 19 of Set 9 | usinsk
# Processing Record 20 of Set 9 | saint-augustin
# Processing Record 21 of Set 9 | sibu
# Processing Record 22 of Set 9 | jalu
# Processing Record 23 of Set 9 | isangel
# Processing Record 24 of Set 9 | nhamunda
# Processing Record 25 of Set 9 | abiy adi
# City not found. Skipping...
# Processing Record 26 of Set 9 | puerto cabezas
# Processing Record 27 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 9 | isla mujeres
# Processing Record 29 of Set 9 | yongan
# Processing Record 30 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 9 | lhokseumawe
# Processing Record 32 of Set 9 | kostroma
# Processing Record 33 of Set 9 | nishihara
# Processing Record 34 of Set 9 | ban dung
# Processing Record 35 of Set 9 | dryden
# Processing Record 36 of Set 9 | lazaro cardenas
# Processing Record 37 of Set 9 | san cristobal
# Processing Record 38 of Set 9 | halifax
# Processing Record 39 of Set 9 | touros
# Processing Record 40 of Set 9 | alta floresta
# Processing Record 41 of Set 9 | pevek
# Processing Record 42 of Set 9 | harnosand
# Processing Record 43 of Set 9 | kutum
# Processing Record 44 of Set 9 | leopold
# Processing Record 45 of Set 9 | dmitriyev-lgovskiy
# City not found. Skipping...
# Processing Record 46 of Set 9 | san juan
# Processing Record 47 of Set 9 | santa fe
# Processing Record 48 of Set 9 | kidal
# Processing Record 49 of Set 9 | evensk
# Processing Record 0 of Set 10 | pangkalanbuun
# Processing Record 1 of Set 10 | turukhansk
# Processing Record 2 of Set 10 | fujimi
# Processing Record 3 of Set 10 | buenaventura
# Processing Record 4 of Set 10 | caravelas
# Processing Record 5 of Set 10 | palenque
# Processing Record 6 of Set 10 | nouadhibou
# Processing Record 7 of Set 10 | kasongo
# Processing Record 8 of Set 10 | erenhot
# Processing Record 9 of Set 10 | bathsheba
# Processing Record 10 of Set 10 | qaqortoq
# Processing Record 11 of Set 10 | shenandoah
# Processing Record 12 of Set 10 | agadez
# Processing Record 13 of Set 10 | bairiki
# Processing Record 14 of Set 10 | bereda
# Processing Record 15 of Set 10 | coruripe
# Processing Record 16 of Set 10 | conceicao do araguaia
# Processing Record 17 of Set 10 | bonthe
# Processing Record 18 of Set 10 | bilma
# Processing Record 19 of Set 10 | alice town
# Processing Record 20 of Set 10 | taywarah
# Processing Record 21 of Set 10 | adrar
# Processing Record 22 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 10 | dolores
# Processing Record 24 of Set 10 | hendijan
# City not found. Skipping...
# Processing Record 25 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 10 | horsham
# Processing Record 27 of Set 10 | dawei
# Processing Record 28 of Set 10 | sault sainte marie
# Processing Record 29 of Set 10 | clearlake
# Processing Record 30 of Set 10 | wielun
# Processing Record 31 of Set 10 | simao
# Processing Record 32 of Set 10 | sauk village
# Processing Record 33 of Set 10 | flinders
# Processing Record 34 of Set 10 | ures
# Processing Record 35 of Set 10 | longhua
# Processing Record 36 of Set 10 | ancud
# Processing Record 37 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 38 of Set 10 | ust-maya
# Processing Record 39 of Set 10 | aksarka
# Processing Record 40 of Set 10 | tekkalakota
# City not found. Skipping...
# Processing Record 41 of Set 10 | bielsk podlaski
# Processing Record 42 of Set 10 | celendin
# Processing Record 43 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 44 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 10 | el campo
# Processing Record 46 of Set 10 | laibin
# Processing Record 47 of Set 10 | basco
# Processing Record 48 of Set 10 | sogdiondon
# City not found. Skipping...
# Processing Record 49 of Set 10 | daxian
# City not found. Skipping...
# Processing Record 0 of Set 11 | burlington
# Processing Record 1 of Set 11 | kruisfontein
# Processing Record 2 of Set 11 | dongkan
# Processing Record 3 of Set 11 | auki
# Processing Record 4 of Set 11 | sanquelim
# Processing Record 5 of Set 11 | casper
# Processing Record 6 of Set 11 | taybad
# Processing Record 7 of Set 11 | balimo
# City not found. Skipping...
# Processing Record 8 of Set 11 | tomatlan
# Processing Record 9 of Set 11 | sambava
# Processing Record 10 of Set 11 | dukat
# Processing Record 11 of Set 11 | puerto madryn
# Processing Record 12 of Set 11 | baruun-urt
# Processing Record 13 of Set 11 | muroto
# Processing Record 14 of Set 11 | geraldton
# Processing Record 15 of Set 11 | tuatapere
# Processing Record 16 of Set 11 | point pedro
# Processing Record 17 of Set 11 | saint-paul
# Processing Record 18 of Set 11 | shenzhen
# Processing Record 19 of Set 11 | panaba
# Processing Record 20 of Set 11 | mehamn
# Processing Record 21 of Set 11 | maceio
# Processing Record 22 of Set 11 | minggang
# Processing Record 23 of Set 11 | solwezi
# Processing Record 24 of Set 11 | redding
# Processing Record 25 of Set 11 | saskylakh
# Processing Record 26 of Set 11 | amuntai
# Processing Record 27 of Set 11 | maumere
# Processing Record 28 of Set 11 | taikang
# Processing Record 29 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 30 of Set 11 | kungurtug
# Processing Record 31 of Set 11 | tunxi
# City not found. Skipping...
# Processing Record 32 of Set 11 | okhotsk
# Processing Record 33 of Set 11 | general roca
# Processing Record 34 of Set 11 | karlskoga
# Processing Record 35 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 36 of Set 11 | willmar
# Processing Record 37 of Set 11 | banyo
# Processing Record 38 of Set 11 | kirakira
# Processing Record 39 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 40 of Set 11 | deputatskiy
# Processing Record 41 of Set 11 | belaya gora
# Processing Record 42 of Set 11 | sioux lookout
# Processing Record 43 of Set 11 | manokwari
# Processing Record 44 of Set 11 | jabinyanah
# Processing Record 45 of Set 11 | bonavista
# Processing Record 46 of Set 11 | bocas del toro
# Processing Record 47 of Set 11 | sept-iles
# Processing Record 48 of Set 11 | chufarovo
# Processing Record 49 of Set 11 | celestun
# Processing Record 0 of Set 12 | las palmas
# Processing Record 1 of Set 12 | college
# Processing Record 2 of Set 12 | bhag
# Processing Record 3 of Set 12 | lujan
# Processing Record 4 of Set 12 | berlevag
# Processing Record 5 of Set 12 | constitucion
# Processing Record 6 of Set 12 | omboue
# Processing Record 7 of Set 12 | thaba-tseka
# Processing Record 8 of Set 12 | san luis
# Processing Record 9 of Set 12 | yerofey pavlovich
# Processing Record 10 of Set 12 | moron
# Processing Record 11 of Set 12 | sibolga
# Processing Record 12 of Set 12 | srivardhan
# Processing Record 13 of Set 12 | faya
# Processing Record 14 of Set 12 | pitea
# Processing Record 15 of Set 12 | barreiras
# Processing Record 16 of Set 12 | along
# Processing Record 17 of Set 12 | andenes
# Processing Record 18 of Set 12 | dingle
# Processing Record 19 of Set 12 | mirabad
# Processing Record 20 of Set 12 | leo
# Processing Record 21 of Set 12 | mendeleyevsk
# Processing Record 22 of Set 12 | acapulco
# Processing Record 23 of Set 12 | roma
# Processing Record 24 of Set 12 | itoman
# Processing Record 25 of Set 12 | pemba
# Processing Record 26 of Set 12 | comodoro rivadavia
# Processing Record 27 of Set 12 | kastamonu
# Processing Record 28 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 29 of Set 12 | grand gaube
# Processing Record 30 of Set 12 | stornoway
# Processing Record 31 of Set 12 | yarkovo
# Processing Record 32 of Set 12 | griffith
# Processing Record 33 of Set 12 | umm bab
# Processing Record 34 of Set 12 | bongor
# Processing Record 35 of Set 12 | pyapon
# Processing Record 36 of Set 12 | paamiut
# Processing Record 37 of Set 12 | coihaique
# Processing Record 38 of Set 12 | prince rupert
# Processing Record 39 of Set 12 | sorong
# Processing Record 40 of Set 12 | dombarovskiy
# Processing Record 41 of Set 12 | jojoima
# Processing Record 42 of Set 12 | fonte boa
# Processing Record 43 of Set 12 | domoni
# Processing Record 44 of Set 12 | kupang
# Processing Record 45 of Set 12 | mooi river
# City not found. Skipping...
# Processing Record 46 of Set 12 | marsh harbour
# Processing Record 47 of Set 12 | tortoli
# Processing Record 48 of Set 12 | avera
# Processing Record 49 of Set 12 | kpandu
# Processing Record 0 of Set 13 | iskateley
# Processing Record 1 of Set 13 | balkanabat
# Processing Record 2 of Set 13 | gravdal
# Processing Record 3 of Set 13 | yeletskiy
# City not found. Skipping...
# Processing Record 4 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 5 of Set 13 | torrington
# Processing Record 6 of Set 13 | kincardine
# Processing Record 7 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 8 of Set 13 | puerto narino
# Processing Record 9 of Set 13 | ahuimanu
# Processing Record 10 of Set 13 | bethel
# Processing Record 11 of Set 13 | sawakin
# Processing Record 12 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 13 of Set 13 | peremyshlyany
# Processing Record 14 of Set 13 | honiara
# Processing Record 15 of Set 13 | bitaogan
# Processing Record 16 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 17 of Set 13 | kalabo
# Processing Record 18 of Set 13 | omsukchan
# Processing Record 19 of Set 13 | najran
# Processing Record 20 of Set 13 | punta de piedra
# Processing Record 21 of Set 13 | lesnoy
# Processing Record 22 of Set 13 | mattru
# Processing Record 23 of Set 13 | barpeta
# Processing Record 24 of Set 13 | itaporanga
# Processing Record 25 of Set 13 | bentiu
# Processing Record 26 of Set 13 | suwannaphum
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_pd = pd.DataFrame(city_data)

city_data_pd.count()
# Out:
# City          562
# Lat           562
# Lng           562
# Max Temp      562
# Humidity      562
# Cloudiness    562
# Wind Speed    562
# Country       562
# Date          562
# dtype: int64

# %%
city_data_pd.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       barrow  71.2906 -156.7887    -23.80        62          90       10.36
# 1      qaanaaq  77.4840  -69.3632    -17.95        63          74        8.28
# 2         hami  42.8000   93.4500     35.83        71           0        2.91
# 3        tiksi  71.6872  128.8694    -15.20        90         100        9.80
# 4  tuktoyaktuk  69.4541 -133.0374    -31.00        68          40       10.36
#
#   Country        Date
# 0      US  1612496250
# 1      GL  1612496370
# 2      CN  1612496370
# 3      RU  1612496140
# 4      CA  1612496370

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data_pd.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  562.000000  562.000000  562.000000  562.000000  562.000000  562.000000
# mean    19.508873   15.695224   50.691762   73.096085   51.149466    7.950836
# std     33.101946   89.684129   31.292082   19.663878   39.061436    5.915963
# min    -54.800000 -179.166700  -41.800000   11.000000    0.000000    0.290000
# 25%     -6.880875  -63.443750   30.975000   63.000000    5.250000    3.440000
# 50%     21.759950   17.714900   60.835000   78.000000   55.000000    6.900000
# 75%     46.466275   96.309625   75.015000   88.000000   90.000000   11.202500
# max     78.218600  178.416700   98.600000  100.000000  100.000000   35.810000
#
#                Date
# count  5.620000e+02
# mean   1.612496e+09
# std    9.768816e+01
# min    1.612496e+09
# 25%    1.612496e+09
# 50%    1.612496e+09
# 75%    1.612496e+09
# max    1.612496e+09

# %%
#Get the indices of cities that have humidity over 100%.
dirty_city_data = city_data_pd[(city_data_pd["Humidity"] > 100)].index

dirty_city_data
# Out:
# Int64Index([], dtype='int64')

# %%
clean_city_data = city_data_pd.drop(dirty_city_data, inplace=False)
clean_city_data.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       barrow  71.2906 -156.7887    -23.80        62          90       10.36
# 1      qaanaaq  77.4840  -69.3632    -17.95        63          74        8.28
# 2         hami  42.8000   93.4500     35.83        71           0        2.91
# 3        tiksi  71.6872  128.8694    -15.20        90         100        9.80
# 4  tuktoyaktuk  69.4541 -133.0374    -31.00        68          40       10.36
#
#   Country        Date
# 0      US  1612496250
# 1      GL  1612496370
# 2      CN  1612496370
# 3      RU  1612496140
# 4      CA  1612496370

# %%
# Extract relevant fields from the data frame
lats = clean_city_data["Lat"]
max_temps = clean_city_data["Max Temp"]
humidity = clean_city_data["Humidity"]
cloudiness = clean_city_data["Cloudiness"]
wind_speed = clean_city_data["Wind Speed"]

# Export the City_Data into a csv
clean_city_data.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(lats, max_temps, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

plt.title("City Latitude vs. Max Temp (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig1.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(lats, humidity, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="cities")

plt.title("City Latitude vs Humidty (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig2.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(lats, cloudiness, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="cities")

plt.title("City Latitude vs Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig3.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(lats, wind_speed, edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="cities")

plt.title("City Latitude vs Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("output_data/Fig4.png")

plt.show()

# %% [markdown]
# ## Linear Regression

# %%
def plot_linear_regression(x_values, title, text_coordinates):
    
    (slope, intercept, rvalue, pvalue, stderr) + linregress(x_value, y_values)
    regress_values = x_values, * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept, 2))
    
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is {rvalue**2}")
    plt.show()

# %%
#North & South Hemisphere 
northern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] >= 0)]
southern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] < 0)]

# %%
# x_values = northern_hemi_df["Lat"]
# y_values = northern_hemi_df["Max Temp"]
# plot_linear_regression(x_values, y_vales, 'Max Temp', (6, 30))
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp', (6,30))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-8c02ab8f78ff> in <module>
#       4 x_values = northern_hemi_df["Lat"]
#       5 y_values = northern_hemi_df["Max Temp"]
# ----> 6 plot_linear_regression(x_values, y_values, 'Max Temp', (6,30))
#
# TypeError: plot_linear_regression() takes 3 positional arguments but 4 were given

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
